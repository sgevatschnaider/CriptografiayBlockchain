# %% [markdown]
# <a href="https://colab.research.google.com/github/sgevatschnaider/CriptografiayBlockchain/blob/main/notebooks/%20BIG_DATA_MATERIAL_ADICIONAL_TRANSFORMER%2C_COMPUTACI%C3%93N_CU%C3%81NTICA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML

# Contenido HTML modificado con índice
html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Computación Cuántica y los LLM: El Futuro de la IA</title>
    <meta name="description" content="Explora cómo los LLM y los transformadores están moldeando el futuro de la computación cuántica e inteligencia artificial.">
    <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
    <style>
        :root {
            --primary-color: #007BFF;
            --secondary-color: #0056b3;
            --text-color: #333;
            --background-color: #f5f5f5;
            --accent-color: #004d40;
            --border-color: #ccc;
            --button-secondary-color: #28a745;
            --button-secondary-hover: #218838;
        }
        body {
            font-family: 'Roboto', Arial, sans-serif;
            line-height: 1.8;
            color: var(--text-color);
            margin: 0;
            padding: 20px;
            background-color: var(--background-color);
        }
        h1 {
            text-align: center;
            font-size: 2.5rem;
            color: var(--accent-color);
            margin-bottom: 20px;
        }
        h2 {
            color: var(--accent-color);
            margin-top: 40px;
        }
        .index {
            background-color: #ffffff;
            padding: 20px;
            border: 1px solid var(--border-color);
            border-radius: 8px;
            max-width: 800px;
            margin: 0 auto 40px auto;
            box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
        }
        .index ul {
            list-style-type: none;
            padding-left: 0;
        }
        .index li {
            margin-bottom: 10px;
        }
        .index a {
            color: var(--primary-color);
            text-decoration: none;
            font-weight: bold;
        }
        .index a:hover {
            text-decoration: underline;
        }
        .collapsible {
            background-color: var(--primary-color);
            color: #fff;
            cursor: pointer;
            padding: 10px 20px;
            border: none;
            border-radius: 5px;
            font-size: 1.2rem;
            text-align: left;
            outline: none;
            margin-top: 20px;
            transition: background-color 0.3s;
            width: 100%;
        }
        .collapsible:hover {
            background-color: var(--secondary-color);
        }
        .collapsible::after {
            content: "▼";
            float: right;
        }
        .collapsible.active::after {
            content: "▲";
        }
        .collapsible-content {
            max-height: 0;
            overflow: hidden;
            transition: max-height 0.5s ease-in-out;
            margin-top: 10px;
            padding-left: 15px;
            border-left: 3px solid var(--primary-color);
        }
        p, ul, ol, table {
            font-size: 1.1rem;
            margin-bottom: 15px;
        }
        ul, ol {
            margin-left: 20px;
        }
        table {
            width: 100%;
            border-collapse: collapse;
            margin: 20px 0;
        }
        table th, table td {
            border: 1px solid var(--border-color);
            padding: 10px;
            text-align: left;
        }
        table th {
            background-color: var(--primary-color);
            color: white;
        }
        .image-container {
            text-align: center;
            margin: 20px auto;
            padding: 10px;
            background-color: #f0f8ff;
            border: 1px solid var(--border-color);
            border-radius: 10px;
            max-width: 800px;
            box-shadow: 0 4px 10px rgba(0, 0, 0, 0.15);
        }
        .image-container img {
            width: 100%;
            max-width: 700px;
            height: auto;
            border-radius: 8px;
        }
        .button-container {
            text-align: center;
            margin-top: 30px;
        }
        .button {
            display: inline-block;
            padding: 10px 20px;
            font-size: 1rem;
            font-weight: bold;
            color: #fff;
            background-color: var(--primary-color);
            text-decoration: none;
            border-radius: 5px;
            transition: background-color 0.3s;
            margin: 5px;
        }
        .button:hover {
            background-color: var(--secondary-color);
        }
        @media (max-width: 600px) {
            h1 {
                font-size: 2rem;
            }
            .collapsible {
                font-size: 1rem;
                padding: 8px 16px;
            }
            .image-container img {
                max-width: 100%;
            }
            table {
                font-size: 1rem;
            }
            .index {
                padding: 15px;
            }
        }
    </style>
</head>
<body>
    <header>
        <h1>Computación Cuántica y los LLM: El Futuro de la IA</h1>
    </header>
    <div class="index">
        <h2>Índice</h2>
        <ul>
            <li><a href="#introduccion">1. Introducción: Una Revolución en la IA</a></li>
            <li><a href="#transformadores">2. ¿Qué son los Transformadores?</a></li>
            <li><a href="#caracteristicas">3. Características Clave de los Transformadores</a></li>
            <li><a href="#alphaqubit">4. AlphaQubit: Transformadores en la Computación Cuántica</a></li>
            <li><a href="#comparativa">5. Comparativa entre LLM y AlphaQubit</a></li>
            <li><a href="#explicacion-imagen">6. Explicación de la Imagen: Corrección de Errores Cuánticos en una Cuadrícula de Qubits</a></li>
            <li><a href="#rol-alphaqubit">7. El Rol de AlphaQubit</a></li>
            <li><a href="#ventajas">8. Ventajas de los Transformadores en AlphaQubit</a></li>
            <li><a href="#conclusion">9. Conclusión: Construyendo el Futuro</a></li>
        </ul>
    </div>
    <main>
        <!-- Introducción -->
        <button class="collapsible" id="introduccion" aria-expanded="false" aria-controls="contenido-introduccion">Introducción: Una Revolución en la IA</button>
        <div id="contenido-introduccion" class="collapsible-content" aria-hidden="true">
            <p>
                Los Large Language Models (LLM), como GPT, han transformado nuestra interacción con la inteligencia artificial. Estos modelos avanzados generan texto coherente, traducen idiomas, resumen información y resuelven problemas complejos. Todo esto es posible gracias a la base que los impulsa: los transformadores.
            </p>
        </div>

        <!-- ¿Qué son los Transformadores? -->
        <button class="collapsible" id="transformadores" aria-expanded="false" aria-controls="contenido-transformadores">¿Qué son los Transformadores?</button>
        <div id="contenido-transformadores" class="collapsible-content" aria-hidden="true">
            <p>
                Un transformador es una arquitectura de aprendizaje profundo que procesa datos secuenciales utilizando el mecanismo de atención. A diferencia de las redes neuronales recurrentes (RNNs) o convolucionales (CNNs), los transformadores no siguen un orden secuencial estricto. En su lugar, analizan toda la entrada simultáneamente, identificando patrones importantes.
            </p>
        </div>

        <!-- Características Clave de los Transformadores -->
        <button class="collapsible" id="caracteristicas" aria-expanded="false" aria-controls="contenido-caracteristicas">Características Clave de los Transformadores</button>
        <div id="contenido-caracteristicas" class="collapsible-content" aria-hidden="true">
            <ul>
                <li><strong>Mecanismo de Atención:</strong> Evalúa qué partes de la entrada son más relevantes para las predicciones.</li>
                <li><strong>Representaciones Vectoriales (Embeddings):</strong> Convierte palabras en vectores numéricos que capturan relaciones semánticas en un espacio continuo.</li>
                <li><strong>Capacidad de Paralelización:</strong> Procesa datos en paralelo, lo que los hace significativamente más rápidos y escalables.</li>
                <li><strong>Generalización y Escalabilidad:</strong> Se adaptan fácilmente a diferentes tareas, como traducción, redacción creativa o simulaciones científicas.</li>
            </ul>
        </div>

        <!-- AlphaQubit: Transformadores en la Computación Cuántica -->
        <button class="collapsible" id="alphaqubit" aria-expanded="false" aria-controls="contenido-alphaqubit">AlphaQubit: Transformadores en la Computación Cuántica</button>
        <div id="contenido-alphaqubit" class="collapsible-content" aria-hidden="true">
            <p>
                Un caso muy interesante de adaptabilidad es AlphaQubit, modelo creado por Google, que aplica transformadores para abordar la corrección de errores en sistemas cuánticos. Esto requiere personalizar la arquitectura para trabajar con datos cuánticos, que son fundamentalmente diferentes del texto procesado por los LLM.
            </p>
        </div>

        <!-- Tabla Comparativa -->
        <button class="collapsible" id="comparativa" aria-expanded="false" aria-controls="contenido-tabla">Comparativa entre LLM y AlphaQubit</button>
        <div id="contenido-tabla" class="collapsible-content" aria-hidden="true">
            <table>
                <thead>
                    <tr>
                        <th>Características</th>
                        <th>LLM</th>
                        <th>AlphaQubit</th>
                    </tr>
                </thead>
                <tbody>
                    <tr>
                        <td>Aplicación Principal</td>
                        <td>Procesamiento de lenguaje natural, generación de texto, traducción, etc.</td>
                        <td>Corrección de errores en sistemas cuánticos.</td>
                    </tr>
                    <tr>
                        <td>Datos de Entrada</td>
                        <td>Texto secuencial.</td>
                        <td>Datos cuánticos de qubits.</td>
                    </tr>
                    <tr>
                        <td>Mecanismo Clave</td>
                        <td>Atención y embeddings.</td>
                        <td>Transformadores adaptados para datos cuánticos.</td>
                    </tr>
                    <tr>
                        <td>Escalabilidad</td>
                        <td>Altamente escalable para múltiples tareas de NLP.</td>
                        <td>Escalable para sistemas cuánticos de mayor complejidad.</td>
                    </tr>
                </tbody>
            </table>
            <p>
                La imagen obtenida muestra este proceso:
            </p>
            <div class="image-container">
                <img
                    src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhT2tIdS9ikTvzgtSjN5yGntE5osZw196rcG1q3aJxVM018amueANXMoXVTMDlSUa_y7fVcCzRNygdefck1D8BeMlWK3P8D9nEshv37gV1ra3lYrJ_Se-F1SOr3xR47X7c0Sv2TYJ3FXphqXy_drrq5dwjTU9GVGH7VCgMsplO-pwV3UXDK5jemo0CeQQc/s320/Animation.gif"
                    alt="Corrección de Errores Cuánticos en una Cuadrícula de Qubits"
                    loading="lazy">
            </div>
        </div>

        <!-- Explicación de la Imagen -->
        <button class="collapsible" id="explicacion-imagen" aria-expanded="false" aria-controls="contenido-imagen">Explicación de la Imagen: Corrección de Errores Cuánticos en una Cuadrícula de Qubits</button>
        <div id="contenido-imagen" class="collapsible-content" aria-hidden="true">
            <p>
                La imagen presentada muestra un ejemplo de cómo se utilizan los códigos de superficie y los transformadores para corregir errores en una cuadrícula de qubits físicos. A continuación, se desglosa cada elemento:
            </p>
            <ol>
                <li>
                    <strong>La Cuadrícula de Qubits Físicos</strong>
                    <ul>
                        <li><strong>Qubits físicos:</strong> Representados como círculos grises, son las unidades básicas de información cuántica.</li>
                        <li><strong>Distancia del código:</strong> El sistema puede detectar y corregir un error físico gracias a su diseño de distancia 3.</li>
                        <li><strong>Objetivo:</strong> Crear un qubit lógico, que sea más resistente al ruido.</li>
                    </ul>
                </li>
                <li>
                    <strong>Los Estabilizadores: Detectores de Errores</strong>
                    <ul>
                        <li><strong>Errores de tipo XXX:</strong> Cambios en el estado binario (∣0⟩|0⟩|0⟩ a ∣1⟩|1⟩|1⟩).</li>
                        <li><strong>Errores de tipo ZZZ:</strong> Alteraciones en la coherencia cuántica.</li>
                        <li><strong>Colores en la cuadrícula:</strong></li>
                        <ul>
                            <li><strong>Gris:</strong> Sin errores detectados.</li>
                            <li><strong>Azul/Magenta:</strong> Activación del estabilizador para señalizar un error.</li>
                        </ul>
                    </ul>
                </li>
            </ol>
        </div>

        <!-- El Rol de AlphaQubit -->
        <button class="collapsible" id="rol-alphaqubit" aria-expanded="false" aria-controls="contenido-rol">El Rol de AlphaQubit</button>
        <div id="contenido-rol" class="collapsible-content" aria-hidden="true">
            <ol>
                <li><strong>Entrada:</strong> Recoge datos de estabilizadores activados.</li>
                <li><strong>Análisis:</strong> Identifica correlaciones espaciales y temporales en los errores.</li>
                <li><strong>Salida:</strong> Genera correcciones precisas para preservar el estado del qubit lógico.</li>
            </ol>
        </div>

        <!-- Ventajas de los Transformadores en AlphaQubit -->
        <button class="collapsible" id="ventajas" aria-expanded="false" aria-controls="contenido-ventajas">Ventajas de los Transformadores en AlphaQubit</button>
        <div id="contenido-ventajas" class="collapsible-content" aria-hidden="true">
            <ul>
                <li><strong>Precisión:</strong> Detectan patrones de error complejos que los métodos tradicionales no pueden resolver.</li>
                <li><strong>Adaptabilidad:</strong> Se entrenan para ajustarse al hardware cuántico específico.</li>
                <li><strong>Escalabilidad:</strong> Funcionan con sistemas cuánticos de mayor tamaño y complejidad.</li>
            </ul>
        </div>

        <!-- Conclusión -->
        <button class="collapsible" id="conclusion" aria-expanded="false" aria-controls="contenido-conclusion">Conclusión: Construyendo el Futuro</button>
        <div id="contenido-conclusion" class="collapsible-content" aria-hidden="true">
            <p>
                Los LLM y los transformadores, desde el procesamiento del lenguaje hasta la computación cuántica, representan una verdadera revolución en cómo abordamos problemas complejos. Modelos como AlphaQubit demuestran que estas tecnologías no solo son versátiles, sino fundamentales para la próxima generación de avances científicos y tecnológicos.
            </p>
            <p>
                <strong>AlphaQubit</strong><br>
                <em>Paper publicado en Nature</em>
            </p>
        </div>

        <!-- Botones -->
        <div class="button-container">
            <a href="https://blog.google/technology/google-deepmind/alphaqubit-quantum-error-correction/" class="button" target="_blank" rel="noopener noreferrer">AlphaQubit tackles one of quantum computing’s biggest challenges</a>
            <a href="https://www.nature.com/articles/s41586-024-08148-8" class="button" target="_blank" rel="noopener noreferrer">Learning high-accuracy error decoding for quantum processors</a>
        </div>
    </main>
    <script>
        const collapsibles = document.querySelectorAll(".collapsible");
        collapsibles.forEach(button => {
            button.addEventListener("click", () => {
                const isActive = button.classList.contains("active");
                // Cierra todos los collapsibles
                collapsibles.forEach(btn => {
                    btn.classList.remove("active");
                    btn.setAttribute("aria-expanded", "false");
                    const content = btn.nextElementSibling;
                    content.setAttribute("aria-hidden", "true");
                    content.style.maxHeight = null;
                });
                // Abre el actual si no estaba abierto
                if (!isActive) {
                    button.classList.toggle("active");
                    button.setAttribute("aria-expanded", "true");
                    const content = button.nextElementSibling;
                    content.setAttribute("aria-hidden", "false");
                    content.style.maxHeight = content.scrollHeight + "px";
                }
            });
        });

        // Funcionalidad del Índice
        const indexLinks = document.querySelectorAll('.index a');
        indexLinks.forEach(link => {
            link.addEventListener('click', (e) => {
                e.preventDefault();
                const targetId = link.getAttribute('href').substring(1);
                const targetButton = document.getElementById(targetId);
                if (targetButton) {
                    targetButton.click();
                    targetButton.scrollIntoView({ behavior: 'smooth', block: 'start' });
                }
            });
        });
    </script>
</body>
</html>
"""

# Mostrar el contenido HTML en Colab
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Computación Cuántica y los LLM: El Futuro de la IA</title>
#     <meta name="description" content="Explora cómo los LLM y los transformadores están moldeando el futuro de la computación cuántica e inteligencia artificial.">
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         :root {
#             --primary-color: #007BFF;
#             --secondary-color: #0056b3;
#             --text-color: #333;
#             --background-color: #f5f5f5;
#             --accent-color: #004d40;
#             --border-color: #ccc;
#             --button-secondary-color: #28a745;
#             --button-secondary-hover: #218838;
#         }
#         body {
#             font-family: 'Roboto', Arial, sans-serif;
#             line-height: 1.8;
# ...

# %%
from IPython.core.display import display, HTML

html_content = r"""
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Computación Cuántica y los LLM: El Futuro de la IA</title>
    <meta name="description" content="Explora cómo los LLM y los transformadores están moldeando el futuro de la computación cuántica e inteligencia artificial.">
    <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
    <style>
        :root {
            --primary-color: #007BFF;
            --secondary-color: #0056b3;
            --text-color: #333;
            --background-color: #f5f5f5;
            --accent-color: #004d40;
            --border-color: #ccc;
            --button-secondary-color: #28a745;
            --button-secondary-hover: #218838;
        }
        body {
            font-family: 'Roboto', Arial, sans-serif;
            line-height: 1.8;
            color: var(--text-color);
            margin: 0;
            padding: 20px;
            background-color: var(--background-color);
        }
        h1 {
            text-align: center;
            font-size: 2.5rem;
            color: var(--accent-color);
            margin-bottom: 20px;
        }
        .collapsible {
            background-color: var(--primary-color);
            color: #fff;
            cursor: pointer;
            padding: 10px 20px;
            border: none;
            border-radius: 5px;
            font-size: 1.2rem;
            text-align: left;
            outline: none;
            margin-top: 20px;
            transition: background-color 0.3s;
        }
        .collapsible:hover {
            background-color: var(--secondary-color);
        }
        .collapsible::after {
            content: "▼";
            float: right;
        }
        .collapsible.active::after {
            content: "▲";
        }
        .collapsible-content {
            max-height: 0;
            overflow: hidden;
            transition: max-height 0.5s ease-in-out;
            margin-top: 10px;
            padding-left: 15px;
            border-left: 3px solid var(--primary-color);
        }
        p, ul, ol, table {
            font-size: 1.1rem;
            margin-bottom: 15px;
        }
        ul, ol {
            margin-left: 20px;
        }
        table {
            width: 100%;
            border-collapse: collapse;
            margin: 20px 0;
        }
        table th, table td {
            border: 1px solid var(--border-color);
            padding: 10px;
            text-align: left;
        }
        table th {
            background-color: var(--primary-color);
            color: white;
        }
        .image-container {
            text-align: center;
            margin: 20px auto;
            padding: 10px;
            background-color: #f0f8ff;
            border: 1px solid var(--border-color);
            border-radius: 10px;
            max-width: 800px;
            box-shadow: 0 4px 10px rgba(0, 0, 0, 0.15);
        }
        .image-container img {
            width: 100%;
            max-width: 700px;
            height: auto;
            border-radius: 8px;
        }
        .button-container {
            text-align: center;
            margin-top: 30px;
        }
        .button {
            display: inline-block;
            padding: 10px 20px;
            font-size: 1rem;
            font-weight: bold;
            color: #fff;
            background-color: var(--primary-color);
            text-decoration: none;
            border-radius: 5px;
            transition: background-color 0.3s;
            margin: 5px;
        }
        .button:hover {
            background-color: var(--secondary-color);
        }
        @media (max-width: 600px) {
            h1 {
                font-size: 2rem;
            }
            .collapsible {
                font-size: 1rem;
                padding: 8px 16px;
            }
            .image-container img {
                max-width: 100%;
            }
            table {
                font-size: 1rem;
            }
        }
    </style>
</head>
<body>
    <header>
        <h1>Computación Cuántica y los LLM: El Futuro de la IA</h1>
    </header>
    <main>
        <!-- Introducción -->
        <button class="collapsible" aria-expanded="false" aria-controls="contenido-introduccion">Introducción: Una Revolución en la IA</button>
        <div id="contenido-introduccion" class="collapsible-content" aria-hidden="true">
            <p>
                Los Large Language Models (LLM), como GPT, han transformado nuestra interacción con la inteligencia artificial. Estos modelos avanzados generan texto coherente, traducen idiomas, resumen información y resuelven problemas complejos. Todo esto es posible gracias a la base que los impulsa: los transformadores.
            </p>
        </div>

        <!-- ¿Qué son los Transformadores? -->
        <button class="collapsible" aria-expanded="false" aria-controls="contenido-transformadores">¿Qué son los Transformadores?</button>
        <div id="contenido-transformadores" class="collapsible-content" aria-hidden="true">
            <p>
                Un transformador es una arquitectura de aprendizaje profundo que procesa datos secuenciales utilizando el mecanismo de atención. A diferencia de las redes neuronales recurrentes (RNNs) o convolucionales (CNNs), los transformadores no siguen un orden secuencial estricto. En su lugar, analizan toda la entrada simultáneamente, identificando patrones importantes.
            </p>
        </div>

        <!-- Características Clave de los Transformadores -->
        <button class="collapsible" aria-expanded="false" aria-controls="contenido-caracteristicas">Características Clave de los Transformadores</button>
        <div id="contenido-caracteristicas" class="collapsible-content" aria-hidden="true">
            <ul>
                <li><strong>Mecanismo de Atención:</strong> Evalúa qué partes de la entrada son más relevantes para las predicciones.</li>
                <li><strong>Representaciones Vectoriales (Embeddings):</strong> Convierte palabras en vectores numéricos que capturan relaciones semánticas en un espacio continuo.</li>
                <li><strong>Capacidad de Paralelización:</strong> Procesa datos en paralelo, lo que los hace significativamente más rápidos y escalables.</li>
                <li><strong>Generalización y Escalabilidad:</strong> Se adaptan fácilmente a diferentes tareas, como traducción, redacción creativa o simulaciones científicas.</li>
            </ul>
        </div>

        <!-- AlphaQubit: Transformadores en la Computación Cuántica -->
        <button class="collapsible" aria-expanded="false" aria-controls="contenido-alphaqubit">AlphaQubit: Transformadores en la Computación Cuántica</button>
        <div id="contenido-alphaqubit" class="collapsible-content" aria-hidden="true">
            <p>
                Un caso muy interesante de adaptabilidad es AlphaQubit, modelo creado por Google, que aplica transformadores para abordar la corrección de errores en sistemas cuánticos. Esto requiere personalizar la arquitectura para trabajar con datos cuánticos, que son fundamentalmente diferentes del texto procesado por los LLM.
            </p>
        </div>

        <!-- Tabla Comparativa -->
        <button class="collapsible" aria-expanded="false" aria-controls="contenido-tabla">Comparativa entre LLM y AlphaQubit</button>
        <div id="contenido-tabla" class="collapsible-content" aria-hidden="true">
            <table>
                <thead>
                    <tr>
                        <th>Características</th>
                        <th>LLM</th>
                        <th>AlphaQubit</th>
                    </tr>
                </thead>
                <tbody>
                    <tr>
                        <td>Aplicación Principal</td>
                        <td>Procesamiento de lenguaje natural, generación de texto, traducción, etc.</td>
                        <td>Corrección de errores en sistemas cuánticos.</td>
                    </tr>
                    <tr>
                        <td>Datos de Entrada</td>
                        <td>Texto secuencial.</td>
                        <td>Datos cuánticos de qubits.</td>
                    </tr>
                    <tr>
                        <td>Mecanismo Clave</td>
                        <td>Atención y embeddings.</td>
                        <td>Transformadores adaptados para datos cuánticos.</td>
                    </tr>
                    <tr>
                        <td>Escalabilidad</td>
                        <td>Altamente escalable para múltiples tareas de NLP.</td>
                        <td>Escalable para sistemas cuánticos de mayor complejidad.</td>
                    </tr>
                </tbody>
            </table>
            <p>
                La imagen obtenida muestra este proceso:
            </p>
            <div class="image-container">
                <img
                    src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhT2tIdS9ikTvzgtSjN5yGntE5osZw196rcG1q3aJxVM018amueANXMoXVTMDlSUa_y7fVcCzRNygdefck1D8BeMlWK3P8D9nEshv37gV1ra3lYrJ_Se-F1SOr3xR47X7c0Sv2TYJ3FXphqXy_drrq5dwjTU9GVGH7VCgMsplO-pwV3UXDK5jemo0CeQQc/s320/Animation.gif"
                    alt="Corrección de Errores Cuánticos en una Cuadrícula de Qubits"
                    loading="lazy">
            </div>
        </div>

        <!-- Explicación de la Imagen -->
        <button class="collapsible" aria-expanded="false" aria-controls="contenido-imagen">Explicación de la Imagen: Corrección de Errores Cuánticos en una Cuadrícula de Qubits</button>
        <div id="contenido-imagen" class="collapsible-content" aria-hidden="true">
            <p>
                La imagen presentada muestra un ejemplo de cómo se utilizan los códigos de superficie y los transformadores para corregir errores en una cuadrícula de qubits físicos. A continuación, se desglosa cada elemento:
            </p>
            <ol>
                <li>
                    <strong>La Cuadrícula de Qubits Físicos</strong>
                    <ul>
                        <li><strong>Qubits físicos:</strong> Representados como círculos grises, son las unidades básicas de información cuántica.</li>
                        <li><strong>Distancia del código:</strong> El sistema puede detectar y corregir un error físico gracias a su diseño de distancia 3.</li>
                        <li><strong>Objetivo:</strong> Crear un qubit lógico, que sea más resistente al ruido.</li>
                    </ul>
                </li>
                <li>
                    <strong>Los Estabilizadores: Detectores de Errores</strong>
                    <ul>
                        <li><strong>Errores de tipo XXX:</strong> Cambios en el estado binario (∣0⟩|0⟩|0⟩ a ∣1⟩|1⟩|1⟩).</li>
                        <li><strong>Errores de tipo ZZZ:</strong> Alteraciones en la coherencia cuántica.</li>
                        <li><strong>Colores en la cuadrícula:</strong></li>
                        <ul>
                            <li><strong>Gris:</strong> Sin errores detectados.</li>
                            <li><strong>Azul/Magenta:</strong> Activación del estabilizador para señalizar un error.</li>
                        </ul>
                    </ul>
                </li>
            </ol>
        </div>

        <!-- El Rol de AlphaQubit -->
        <button class="collapsible" aria-expanded="false" aria-controls="contenido-rol">El Rol de AlphaQubit</button>
        <div id="contenido-rol" class="collapsible-content" aria-hidden="true">
            <ol>
                <li><strong>Entrada:</strong> Recoge datos de estabilizadores activados.</li>
                <li><strong>Análisis:</strong> Identifica correlaciones espaciales y temporales en los errores.</li>
                <li><strong>Salida:</strong> Genera correcciones precisas para preservar el estado del qubit lógico.</li>
            </ol>
        </div>

        <!-- Ventajas de los Transformadores en AlphaQubit -->
        <button class="collapsible" aria-expanded="false" aria-controls="contenido-ventajas">Ventajas de los Transformadores en AlphaQubit</button>
        <div id="contenido-ventajas" class="collapsible-content" aria-hidden="true">
            <ul>
                <li><strong>Precisión:</strong> Detectan patrones de error complejos que los métodos tradicionales no pueden resolver.</li>
                <li><strong>Adaptabilidad:</strong> Se entrenan para ajustarse al hardware cuántico específico.</li>
                <li><strong>Escalabilidad:</strong> Funcionan con sistemas cuánticos de mayor tamaño y complejidad.</li>
            </ul>
        </div>

        <!-- Conclusión -->
        <button class="collapsible" aria-expanded="false" aria-controls="contenido-conclusion">Conclusión: Construyendo el Futuro</button>
        <div id="contenido-conclusion" class="collapsible-content" aria-hidden="true">
            <p>
                Los LLM y los transformadores, desde el procesamiento del lenguaje hasta la computación cuántica, representan una verdadera revolución en cómo abordamos problemas complejos. Modelos como AlphaQubit demuestran que estas tecnologías no solo son versátiles, sino fundamentales para la próxima generación de avances científicos y tecnológicos.
            </p>
            <p>
                <strong>AlphaQubit</strong><br>
                <em>Paper publicado en Nature</em>
            </p>
        </div>

        <!-- Botones -->
        <div class="button-container">
            <a href="https://blog.google/technology/google-deepmind/alphaqubit-quantum-error-correction/" class="button" target="_blank" rel="noopener noreferrer">AlphaQubit tackles one of quantum computing’s biggest challenges</a>
            <a href="https://www.nature.com/articles/s41586-024-08148-8" class="button" target="_blank" rel="noopener noreferrer">Learning high-accuracy error decoding for quantum processors</a>
        </div>
    </main>
    <script>
        const collapsibles = document.querySelectorAll(".collapsible");
        collapsibles.forEach(button => {
            button.addEventListener("click", () => {
                const isActive = button.classList.contains("active");
                // Cierra todos los collapsibles
                collapsibles.forEach(btn => {
                    btn.classList.remove("active");
                    btn.setAttribute("aria-expanded", "false");
                    const content = btn.nextElementSibling;
                    content.setAttribute("aria-hidden", "true");
                    content.style.maxHeight = null;
                });
                // Abre el actual si no estaba abierto
                if (!isActive) {
                    button.classList.toggle("active");
                    button.setAttribute("aria-expanded", "true");
                    const content = button.nextElementSibling;
                    content.setAttribute("aria-hidden", "false");
                    content.style.maxHeight = content.scrollHeight + "px";
                }
            });
        });
    </script>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Computación Cuántica y los LLM: El Futuro de la IA</title>
#     <meta name="description" content="Explora cómo los LLM y los transformadores están moldeando el futuro de la computación cuántica e inteligencia artificial.">
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         :root {
#             --primary-color: #007BFF;
#             --secondary-color: #0056b3;
#             --text-color: #333;
#             --background-color: #f5f5f5;
#             --accent-color: #004d40;
#             --border-color: #ccc;
#             --button-secondary-color: #28a745;
#             --button-secondary-hover: #218838;
#         }
#         body {
#             font-family: 'Roboto', Arial, sans-serif;
#             line-height: 1.8;
# ...

# %%
from IPython.core.display import display, HTML

# Contenido HTML completo actualizado con el índice y la nueva sección
html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Computación Cuántica y los LLM: El Futuro de la IA</title>
    <meta name="description" content="Explora cómo los LLM y los transformadores están moldeando el futuro de la computación cuántica e inteligencia artificial.">
    <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
    <style>
        :root {
            --primary-color: #007BFF;
            --secondary-color: #0056b3;
            --text-color: #333;
            --background-color: #f5f5f5;
            --accent-color: #004d40;
            --border-color: #ccc;
            --button-secondary-color: #28a745;
            --button-secondary-hover: #218838;
        }
        body {
            font-family: 'Roboto', Arial, sans-serif;
            line-height: 1.8;
            color: var(--text-color);
            margin: 0;
            padding: 20px;
            background-color: var(--background-color);
        }
        h1 {
            text-align: center;
            font-size: 2.5rem;
            color: var(--accent-color);
            margin-bottom: 20px;
        }
        h2 {
            color: var(--accent-color);
            margin-top: 40px;
        }
        .index {
            background-color: #ffffff;
            padding: 20px;
            border: 1px solid var(--border-color);
            border-radius: 8px;
            max-width: 800px;
            margin: 0 auto 40px auto;
            box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
        }
        .index ul {
            list-style-type: none;
            padding-left: 0;
        }
        .index li {
            margin-bottom: 10px;
        }
        .index a {
            color: var(--primary-color);
            text-decoration: none;
            font-weight: bold;
        }
        .index a:hover {
            text-decoration: underline;
        }
        .collapsible {
            background-color: var(--primary-color);
            color: #fff;
            cursor: pointer;
            padding: 10px 20px;
            border: none;
            border-radius: 5px;
            font-size: 1.2rem;
            text-align: left;
            outline: none;
            margin-top: 20px;
            transition: background-color 0.3s;
            width: 100%;
        }
        .collapsible:hover {
            background-color: var(--secondary-color);
        }
        .collapsible::after {
            content: "▼";
            float: right;
        }
        .collapsible.active::after {
            content: "▲";
        }
        .collapsible-content {
            max-height: 0;
            overflow: hidden;
            transition: max-height 0.5s ease-in-out;
            margin-top: 10px;
            padding-left: 15px;
            border-left: 3px solid var(--primary-color);
        }
        p, ul, ol, table {
            font-size: 1.1rem;
            margin-bottom: 15px;
        }
        ul, ol {
            margin-left: 20px;
        }
        table {
            width: 100%;
            border-collapse: collapse;
            margin: 20px 0;
        }
        table th, table td {
            border: 1px solid var(--border-color);
            padding: 10px;
            text-align: left;
        }
        table th {
            background-color: var(--primary-color);
            color: white;
        }
        .image-container {
            text-align: center;
            margin: 20px auto;
            padding: 10px;
            background-color: #f0f8ff;
            border: 1px solid var(--border-color);
            border-radius: 10px;
            max-width: 800px;
            box-shadow: 0 4px 10px rgba(0, 0, 0, 0.15);
        }
        .image-container img {
            width: 100%;
            max-width: 700px;
            height: auto;
            border-radius: 8px;
        }
        .button-container {
            text-align: center;
            margin-top: 30px;
        }
        .button {
            display: inline-block;
            padding: 10px 20px;
            font-size: 1rem;
            font-weight: bold;
            color: #fff;
            background-color: var(--primary-color);
            text-decoration: none;
            border-radius: 5px;
            transition: background-color 0.3s;
            margin: 5px;
        }
        .button:hover {
            background-color: var(--secondary-color);
        }
        @media (max-width: 600px) {
            h1 {
                font-size: 2rem;
            }
            .collapsible {
                font-size: 1rem;
                padding: 8px 16px;
            }
            .image-container img {
                max-width: 100%;
            }
            table {
                font-size: 1rem;
            }
            .index {
                padding: 15px;
            }
        }
    </style>
</head>
<body>
    <header>
        <h1>Computación Cuántica y los LLM: El Futuro de la IA</h1>
    </header>
    <div class="index">
        <h2>Índice</h2>
        <ul>
            <li><a href="#introduccion">1. Introducción: Una Revolución en la IA</a></li>
            <li><a href="#transformadores">2. ¿Qué son los Transformadores?</a></li>
            <li><a href="#caracteristicas">3. Características Clave de los Transformadores</a></li>
            <li><a href="#alphaqubit">4. AlphaQubit: Transformadores en la Computación Cuántica</a></li>
            <li><a href="#comparativa">5. Comparativa entre LLM y AlphaQubit</a></li>
            <li><a href="#explicacion-imagen">6. Explicación de la Imagen: Corrección de Errores Cuánticos en una Cuadrícula de Qubits</a></li>
            <li><a href="#rol-alphaqubit">7. El Rol de AlphaQubit</a></li>
            <li><a href="#relacion">8. Relación entre Estabilizadores y Transformers</a></li>
            <li><a href="#ventajas">9. Ventajas de los Transformadores en AlphaQubit</a></li>
            <li><a href="#conclusion">10. Conclusión: Construyendo el Futuro</a></li>
        </ul>
    </div>
    <main>
        <!-- Introducción -->
        <button class="collapsible" id="introduccion" aria-expanded="false" aria-controls="contenido-introduccion">Introducción: Una Revolución en la IA</button>
        <div id="contenido-introduccion" class="collapsible-content" aria-hidden="true">
            <p>
                Los Large Language Models (LLM), como GPT, han transformado nuestra interacción con la inteligencia artificial. Estos modelos avanzados generan texto coherente, traducen idiomas, resumen información y resuelven problemas complejos. Todo esto es posible gracias a la base que los impulsa: los transformadores.
            </p>
        </div>

        <!-- ¿Qué son los Transformadores? -->
        <button class="collapsible" id="transformadores" aria-expanded="false" aria-controls="contenido-transformadores">¿Qué son los Transformadores?</button>
        <div id="contenido-transformadores" class="collapsible-content" aria-hidden="true">
            <p>
                Un transformador es una arquitectura de aprendizaje profundo que procesa datos secuenciales utilizando el mecanismo de atención. A diferencia de las redes neuronales recurrentes (RNNs) o convolucionales (CNNs), los transformadores no siguen un orden secuencial estricto. En su lugar, analizan toda la entrada simultáneamente, identificando patrones importantes.
            </p>
        </div>

        <!-- Características Clave de los Transformadores -->
        <button class="collapsible" id="caracteristicas" aria-expanded="false" aria-controls="contenido-caracteristicas">Características Clave de los Transformadores</button>
        <div id="contenido-caracteristicas" class="collapsible-content" aria-hidden="true">
            <ul>
                <li><strong>Mecanismo de Atención:</strong> Evalúa qué partes de la entrada son más relevantes para las predicciones.</li>
                <li><strong>Representaciones Vectoriales (Embeddings):</strong> Convierte palabras en vectores numéricos que capturan relaciones semánticas en un espacio continuo.</li>
                <li><strong>Capacidad de Paralelización:</strong> Procesa datos en paralelo, lo que los hace significativamente más rápidos y escalables.</li>
                <li><strong>Generalización y Escalabilidad:</strong> Se adaptan fácilmente a diferentes tareas, como traducción, redacción creativa o simulaciones científicas.</li>
            </ul>
        </div>

        <!-- AlphaQubit: Transformadores en la Computación Cuántica -->
        <button class="collapsible" id="alphaqubit" aria-expanded="false" aria-controls="contenido-alphaqubit">AlphaQubit: Transformadores en la Computación Cuántica</button>
        <div id="contenido-alphaqubit" class="collapsible-content" aria-hidden="true">
            <p>
                Un caso muy interesante de adaptabilidad es AlphaQubit, modelo creado por Google, que aplica transformadores para abordar la corrección de errores en sistemas cuánticos. Esto requiere personalizar la arquitectura para trabajar con datos cuánticos, que son fundamentalmente diferentes del texto procesado por los LLM.
            </p>
        </div>

        <!-- Tabla Comparativa -->
        <button class="collapsible" id="comparativa" aria-expanded="false" aria-controls="contenido-tabla">Comparativa entre LLM y AlphaQubit</button>
        <div id="contenido-tabla" class="collapsible-content" aria-hidden="true">
            <table>
                <thead>
                    <tr>
                        <th>Características</th>
                        <th>LLM</th>
                        <th>AlphaQubit</th>
                    </tr>
                </thead>
                <tbody>
                    <tr>
                        <td>Aplicación Principal</td>
                        <td>Procesamiento de lenguaje natural, generación de texto, traducción, etc.</td>
                        <td>Corrección de errores en sistemas cuánticos.</td>
                    </tr>
                    <tr>
                        <td>Datos de Entrada</td>
                        <td>Texto secuencial.</td>
                        <td>Datos cuánticos de qubits.</td>
                    </tr>
                    <tr>
                        <td>Mecanismo Clave</td>
                        <td>Atención y embeddings.</td>
                        <td>Transformadores adaptados para datos cuánticos.</td>
                    </tr>
                    <tr>
                        <td>Escalabilidad</td>
                        <td>Altamente escalable para múltiples tareas de NLP.</td>
                        <td>Escalable para sistemas cuánticos de mayor complejidad.</td>
                    </tr>
                </tbody>
            </table>
            <p>
                La imagen obtenida muestra este proceso:
            </p>
            <div class="image-container">
                <img
                    src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhT2tIdS9ikTvzgtSjN5yGntE5osZw196rcG1q3aJxVM018amueANXMoXVTMDlSUa_y7fVcCzRNygdefck1D8BeMlWK3P8D9nEshv37gV1ra3lYrJ_Se-F1SOr3xR47X7c0Sv2TYJ3FXphqXy_drrq5dwjTU9GVGH7VCgMsplO-pwV3UXDK5jemo0CeQQc/s320/Animation.gif"
                    alt="Corrección de Errores Cuánticos en una Cuadrícula de Qubits"
                    loading="lazy">
            </div>
        </div>

        <!-- Explicación de la Imagen -->
        <button class="collapsible" id="explicacion-imagen" aria-expanded="false" aria-controls="contenido-imagen">Explicación de la Imagen: Corrección de Errores Cuánticos en una Cuadrícula de Qubits</button>
        <div id="contenido-imagen" class="collapsible-content" aria-hidden="true">
            <p>
                La imagen presentada muestra un ejemplo de cómo se utilizan los códigos de superficie y los transformadores para corregir errores en una cuadrícula de qubits físicos. A continuación, se desglosa cada elemento:
            </p>
            <ol>
                <li>
                    <strong>La Cuadrícula de Qubits Físicos</strong>
                    <ul>
                        <li><strong>Qubits físicos:</strong> Representados como círculos grises, son las unidades básicas de información cuántica.</li>
                        <li><strong>Distancia del código:</strong> El sistema puede detectar y corregir un error físico gracias a su diseño de distancia 3.</li>
                        <li><strong>Objetivo:</strong> Crear un qubit lógico, que sea más resistente al ruido.</li>
                    </ul>
                </li>
                <li>
                    <strong>Los Estabilizadores: Detectores de Errores</strong>
                    <ul>
                        <li><strong>Errores de tipo XXX:</strong> Cambios en el estado binario (∣0⟩|0⟩|0⟩ a ∣1⟩|1⟩|1⟩).</li>
                        <li><strong>Errores de tipo ZZZ:</strong> Alteraciones en la coherencia cuántica.</li>
                        <li><strong>Colores en la cuadrícula:</strong></li>
                        <ul>
                            <li><strong>Gris:</strong> Sin errores detectados.</li>
                            <li><strong>Azul/Magenta:</strong> Activación del estabilizador para señalizar un error.</li>
                        </ul>
                    </ul>
                </li>
            </ol>
        </div>

        <!-- El Rol de AlphaQubit -->
        <button class="collapsible" id="rol-alphaqubit" aria-expanded="false" aria-controls="contenido-rol">El Rol de AlphaQubit</button>
        <div id="contenido-rol" class="collapsible-content" aria-hidden="true">
            <ol>
                <li><strong>Entrada:</strong> Recoge datos de estabilizadores activados.</li>
                <li><strong>Análisis:</strong> Identifica correlaciones espaciales y temporales en los errores.</li>
                <li><strong>Salida:</strong> Genera correcciones precisas para preservar el estado del qubit lógico.</li>
            </ol>
        </div>

        <!-- Relación entre Estabilizadores y Transformers -->
        <button class="collapsible" id="relacion" aria-expanded="false" aria-controls="contenido-relacion">Relación entre Estabilizadores y Transformers</button>
        <div id="contenido-relacion" class="collapsible-content" aria-hidden="true">
            <h3>Estabilizadores:</h3>
            <ul>
                <li>Generan los datos de medición (síndromes) que describen inconsistencias en el sistema.</li>
                <li>Son elementos físicos que operan en la cuadrícula de qubits y son parte del hardware del sistema cuántico.</li>
            </ul>
            <h3>Transformers:</h3>
            <ul>
                <li>Procesan los datos generados por los estabilizadores para analizar patrones de errores.</li>
                <li>Forman parte del software de inteligencia artificial (el decodificador AlphaQubit) y son responsables de decidir las correcciones.</li>
            </ul>
            <h3>En resumen:</h3>
            <ul>
                <li><strong>Estabilizadores:</strong> “Detectores” físicos que observan errores.</li>
                <li><strong>Transformers:</strong> “Decodificadores” basados en inteligencia artificial que analizan los datos de los estabilizadores y deciden cómo corregir los errores.</li>
            </ul>
        </div>

        <!-- Ventajas de los Transformadores en AlphaQubit -->
        <button class="collapsible" id="ventajas" aria-expanded="false" aria-controls="contenido-ventajas">Ventajas de los Transformadores en AlphaQubit</button>
        <div id="contenido-ventajas" class="collapsible-content" aria-hidden="true">
            <ul>
                <li><strong>Precisión:</strong> Detectan patrones de error complejos que los métodos tradicionales no pueden resolver.</li>
                <li><strong>Adaptabilidad:</strong> Se entrenan para ajustarse al hardware cuántico específico.</li>
                <li><strong>Escalabilidad:</strong> Funcionan con sistemas cuánticos de mayor tamaño y complejidad.</li>
            </ul>
        </div>

        <!-- Conclusión -->
        <button class="collapsible" id="conclusion" aria-expanded="false" aria-controls="contenido-conclusion">Conclusión: Construyendo el Futuro</button>
        <div id="contenido-conclusion" class="collapsible-content" aria-hidden="true">
            <p>
                Los LLM y los transformadores, desde el procesamiento del lenguaje hasta la computación cuántica, representan una verdadera revolución en cómo abordamos problemas complejos. Modelos como AlphaQubit demuestran que estas tecnologías no solo son versátiles, sino fundamentales para la próxima generación de avances científicos y tecnológicos.
            </p>
            <p>
                <strong>AlphaQubit</strong><br>
                <em>Paper publicado en Nature</em>
            </p>
        </div>

        <!-- Botones -->
        <div class="button-container">
            <a href="https://blog.google/technology/google-deepmind/alphaqubit-quantum-error-correction/" class="button" target="_blank" rel="noopener noreferrer">AlphaQubit tackles one of quantum computing’s biggest challenges</a>
            <a href="https://www.nature.com/articles/s41586-024-08148-8" class="button" target="_blank" rel="noopener noreferrer">Learning high-accuracy error decoding for quantum processors</a>
        </div>
    </main>
    <script>
        const collapsibles = document.querySelectorAll(".collapsible");
        collapsibles.forEach(button => {
            button.addEventListener("click", () => {
                const isActive = button.classList.contains("active");
                // Cierra todos los collapsibles
                collapsibles.forEach(btn => {
                    btn.classList.remove("active");
                    btn.setAttribute("aria-expanded", "false");
                    const content = btn.nextElementSibling;
                    content.setAttribute("aria-hidden", "true");
                    content.style.maxHeight = null;
                });
                // Abre el actual si no estaba abierto
                if (!isActive) {
                    button.classList.toggle("active");
                    button.setAttribute("aria-expanded", "true");
                    const content = button.nextElementSibling;
                    content.setAttribute("aria-hidden", "false");
                    content.style.maxHeight = content.scrollHeight + "px";
                }
            });
        });

        // Funcionalidad del Índice
        const indexLinks = document.querySelectorAll('.index a');
        indexLinks.forEach(link => {
            link.addEventListener('click', (e) => {
                e.preventDefault();
                const targetId = link.getAttribute('href').substring(1);
                const targetButton = document.getElementById(targetId);
                if (targetButton) {
                    targetButton.click();
                    targetButton.scrollIntoView({ behavior: 'smooth', block: 'start' });
                }
            });
        });
    </script>
</body>
</html>
"""

# Mostrar el contenido HTML en Colab
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Computación Cuántica y los LLM: El Futuro de la IA</title>
#     <meta name="description" content="Explora cómo los LLM y los transformadores están moldeando el futuro de la computación cuántica e inteligencia artificial.">
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         :root {
#             --primary-color: #007BFF;
#             --secondary-color: #0056b3;
#             --text-color: #333;
#             --background-color: #f5f5f5;
#             --accent-color: #004d40;
#             --border-color: #ccc;
#             --button-secondary-color: #28a745;
#             --button-secondary-hover: #218838;
#         }
#         body {
#             font-family: 'Roboto', Arial, sans-serif;
#             line-height: 1.8;
# ...
